# %% [markdown]
# https://medium.com/grabngoinfo/hyperparameter-tuning-for-bertopic-model-in-python-104445778347

# %% [markdown]
# https://maartengr.github.io/BERTopic/api/bertopic.html

# %%
# Install bertopic
# !pip install bertopic flair
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.15.0-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 11.8 MB/s eta 0:00:00
# Collecting flair
#   Downloading flair-0.12.2-py3-none-any.whl (373 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.1/373.1 kB 38.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.22.4)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 98.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.65.0)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 314.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.13.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from flair) (2.8.2)
# Requirement already satisfied: torch!=1.8,>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from flair) (2.0.1+cu118)
# Requirement already satisfied: gensim>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from flair) (4.3.1)
# Collecting segtok>=1.5.7 (from flair)
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from flair) (3.7.1)
# Collecting mpld3==0.3 (from flair)
#   Downloading mpld3-0.3.tar.gz (788 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.5/788.5 kB 54.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sqlitedict>=1.6.0 (from flair)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deprecated>=1.2.4 (from flair)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: hyperopt>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from flair) (0.2.7)
# Collecting boto3 (from flair)
#   Downloading boto3-1.26.155-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 12.3 MB/s eta 0:00:00
# Collecting transformers[sentencepiece]>=4.18.0 (from flair)
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 75.4 MB/s eta 0:00:00
# Collecting bpemb>=0.3.2 (from flair)
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from flair) (2022.10.31)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from flair) (0.8.10)
# Collecting langdetect (from flair)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 43.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from flair) (4.9.2)
# Collecting ftfy (from flair)
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.2 MB/s eta 0:00:00
# Collecting janome (from flair)
#   Downloading Janome-0.4.2-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 70.9 MB/s eta 0:00:00
# Collecting gdown==4.4.0 (from flair)
#   Downloading gdown-4.4.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting huggingface-hub>=0.10.0 (from flair)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 23.4 MB/s eta 0:00:00
# Collecting conllu>=4.0 (from flair)
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from flair) (9.1.0)
# Collecting wikipedia-api (from flair)
#   Downloading Wikipedia_API-0.5.8-py3-none-any.whl (13 kB)
# Collecting pptree (from flair)
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pytorch-revgrad (from flair)
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Collecting transformer-smaller-training-vocab>=0.2.1 (from flair)
#   Downloading transformer_smaller_training_vocab-0.2.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->flair) (3.12.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->flair) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->flair) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->flair) (4.11.2)
# Collecting sentencepiece (from bpemb>=0.3.2->flair)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.8 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.4->flair) (1.14.1)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim>=3.8.0->flair) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=3.8.0->flair) (6.3.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.34)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (2023.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (23.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair) (3.1)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair) (0.18.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair) (2.2.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair) (0.10.9.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.8,>=1.5.0->flair) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.8,>=1.5.0->flair) (16.0.5)
# Collecting datasets<3.0.0,>=2.0.0 (from transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading datasets-2.13.0-py3-none-any.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 41.5 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers[sentencepiece]>=4.18.0->flair)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 73.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers[sentencepiece]>=4.18.0->flair)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<=3.20.3 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.18.0->flair) (3.20.3)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 62.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting botocore<1.30.0,>=1.29.155 (from boto3->flair)
#   Downloading botocore-1.29.155-py3-none-any.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 65.1 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->flair)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3->flair)
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->flair) (0.2.6)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.30.0,>=1.29.155->boto3->flair) (1.26.15)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.0 MB/s eta 0:00:00
# Collecting xxhash (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 2.0 MB/s eta 0:00:00
# Collecting multiprocess (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 17.2 MB/s eta 0:00:00
# Collecting aiohttp (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.6 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.4.0->flair) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.4.0->flair) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.4.0->flair) (3.4)
# Collecting accelerate>=0.20.2 (from transformers[sentencepiece]>=4.18.0->flair)
#   Downloading accelerate-0.20.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown==4.4.0->flair) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.8,>=1.5.0->flair) (2.1.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.4.0->flair) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.8,>=1.5.0->flair) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.2->transformers[sentencepiece]>=4.18.0->flair) (5.9.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.9 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.2 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 3.4 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Building wheels for collected packages: gdown, mpld3, hdbscan, sentence-transformers, sqlitedict, umap-learn, langdetect, pptree, pynndescent
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14759 sha256=8088a2a2f24f52479ce9929d0f906e72fff1caa7d3033536da34b0b6564d073a
#   Stored in directory: /root/.cache/pip/wheels/03/0b/3f/6ddf67a417a5b400b213b0bb772a50276c199a386b12c06bfc
#   Building wheel for mpld3 (setup.py) ... done
#   Created wheel for mpld3: filename=mpld3-0.3-py3-none-any.whl size=116685 sha256=612cf54f75ba44c01d5f138b5e3df00cb5624b0e01e516a1fa12abcae8593934
#   Stored in directory: /root/.cache/pip/wheels/9c/92/f7/45d9aac5dcfb1c2a1761a272365599cc7ba1050ce211a3fd9a
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp310-cp310-linux_x86_64.whl size=3542004 sha256=7f7516262605e9d21581a412bd866d32a1ef38965476e29d23e9409ef8644f79
#   Stored in directory: /root/.cache/pip/wheels/dc/52/e3/6c6b60b126b4d5c4370cb5ac071b82950f91649d62d72f7f56
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=85e20b6d8005b297a6edb27e67a1870f11a24a0c23bfc2a94c73a2abff10dc7e
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=25263dea18b25197129547f7371df523608572373e67c2a4dfcdeaa3ab5e3b05
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82816 sha256=669f4cf314beabb65d2ebf72ed75f671cf045dc9db122d4d1fbdf32abe69ab83
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=cced3f1f5c8ed0b1ca7ce4d7cf441b6f706a67bb445c9b78f6b4ec8914cb8b4d
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4609 sha256=c8cdc3045e193f7e16de1d57f576237ad5dcc4ac50aba08903863797b5b29512
#   Stored in directory: /root/.cache/pip/wheels/9f/b6/0e/6f26eb9e6eb53ff2107a7888d72b5a6a597593956113037828
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55622 sha256=9a9cc435bb2f1ef374f00384b0ef3fa4c7165f6cd1d5494a2e3c0b9dcd73d9fa
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built gdown mpld3 hdbscan sentence-transformers sqlitedict umap-learn langdetect pptree pynndescent
# Installing collected packages: tokenizers, sqlitedict, sentencepiece, safetensors, pptree, mpld3, janome, xxhash, segtok, multidict, langdetect, jmespath, ftfy, frozenlist, dill, deprecated, conllu, async-timeout, yarl, wikipedia-api, multiprocess, huggingface-hub, botocore, aiosignal, transformers, s3transfer, pynndescent, hdbscan, gdown, bpemb, aiohttp, umap-learn, boto3, datasets, accelerate, transformer-smaller-training-vocab, sentence-transformers, pytorch-revgrad, flair, bertopic
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# Successfully installed accelerate-0.20.3 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 bertopic-0.15.0 boto3-1.26.155 botocore-1.29.155 bpemb-0.3.4 conllu-4.5.2 datasets-2.13.0 deprecated-1.2.14 dill-0.3.6 flair-0.12.2 frozenlist-1.3.3 ftfy-6.1.1 gdown-4.4.0 hdbscan-0.8.29 huggingface-hub-0.15.1 janome-0.4.2 jmespath-1.0.1 langdetect-1.0.9 mpld3-0.3 multidict-6.0.4 multiprocess-0.70.14 pptree-3.1 pynndescent-0.5.10 pytorch-revgrad-0.2.0 s3transfer-0.6.1 safetensors-0.3.1 segtok-1.5.11 sentence-transformers-2.2.2 sentencepiece-0.1.99 sqlitedict-2.1.0 tokenizers-0.13.3 transformer-smaller-training-vocab-0.2.4 transformers-4.30.2 umap-learn-0.5.3 wikipedia-api-0.5.8 xxhash-3.2.0 yarl-1.9.2

# %%
# Data processing
import pandas as pd
import numpy as np
# Dimension reduction
from umap import UMAP
from sklearn.decomposition import PCA
# Clustering
from hdbscan import HDBSCAN
from sklearn.cluster import KMeans
# Count vectorization
from sklearn.feature_extraction.text import CountVectorizer
# Sentence transformer
from sentence_transformers import SentenceTransformer
# Flair
from transformers.pipelines import pipeline
from flair.embeddings import TransformerDocumentEmbeddings, WordEmbeddings, DocumentPoolEmbeddings, StackedEmbeddings
# Topic model
from bertopic import BERTopic

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Change directory
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks")
# Print out the current directory
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks

# %%
# Read in data
amz_review = pd.read_csv('amazon_cells_labelled.txt', sep='\t', names=['review', 'label'])
# Drop te label
amz_review = amz_review.drop('label', axis=1);
# Take a look at the data
amz_review.head()
# Out:
#                                               review
# 0  So there is no way for me to plug it in here i...
# 1                        Good case, Excellent value.
# 2                             Great for the jawbone.
# 3  Tied to charger for conversations lasting more...
# 4                                  The mic is great.

# %% [markdown]
# Dimensionality reduction is necessary because the clustering model works better for low-dimension data than high-dimension data. The document embeddings usually have hundreds of dimensions, so we need to reduce the dimensionality before passing the embeddings to a clustering model.
#
# The default algorithm for dimension reduction is UMAP (Uniform Manifold Approximation & Projection). Compared with other dimension reduction techniques such as PCA (Principle Component Analysis), UMAP maintains the data’s local and global structure when reducing the dimensionality, which is important for representing the semantics of the text data. The UMAP model accepts customized hyperparameters.

# %%
# Initiate UMAP
umap_model = UMAP(n_neighbors=15,
                  n_components=5,
                  min_dist=0.0,
                  metric='cosine',
                  random_state=100)
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
#     Topic  ...                                Representative_Docs
# 0      -1  ...  [I have been very happy with the 510 and have ...
# 1       0  ...  [Great Phone., It was a great phone., This is ...
# 2       1  ...  [The sound is clear and the people I talk to o...
# 3       2  ...  [Excellent product for the price., Great produ...
# 4       3  ...  [It was quite comfortable in the ear., It fits...
# 5       4  ...  [My headset works just peachy-keen., Best head...
# 6       5  ...  [Battery has no life., Battery life is also gr...
# 7       6  ...       [Works great., Works great!., Works great!.]
# 8       7  ...  [I purcashed this for the car charger and it d...
# 9       8  ...  [This case seems well made., Great case and pr...
# 10      9  ...  [I would recommend this., I would not recommen...
# 11     10  ...  [A PIECE OF JUNK THAT BROKE AFTER BEING ON MY ...
# 12     11  ...  [Bad Reception., I great reception all the tim...
# 13     12  ...  [disappointed., VERY DISAPPOINTED., very disap...
# 14     13  ...  [Great it was new packaged nice works good, no...
# 15     14  ...  [But, in any case, the best part is, you can d...
# 16     15  ...  [Pros:-Good camera - very nice pictures , also...
# 17     16  ...  [Worst Customer Service Ever., Customer servic...
# 18     17  ...  [Don't waste your money!., don't waste your mo...
# 19     18  ...  [The buttons for on and off are bad., It feels...
# 20     19  ...  [I love this device., The handsfree part works...
# 21     20  ...  [The color is even prettier than I thought it ...
# 22     21  ...  [The tracfonewebsite is user friendly and make...
# 23     22  ...  [I wish I could return the unit and get back m...
# 24     23  ...  [Best I've found so far .... I've tried 2 othe...
# 25     24  ...  [I advise EVERYONE DO NOT BE FOOLED!, Warning ...
#
# [26 rows x 5 columns]

# %%
# PCA for dimensionality reduction
pca_model = PCA(n_components=15)
# Initiate BERTopic
topic_model = BERTopic(umap_model=pca_model)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
#    Topic  ...                                Representative_Docs
# 0     -1  ...  [It is simple to use and I like it., The price...
# 1      0  ...  [very disappointed., VERY DISAPPOINTED., If yo...
# 2      1  ...  [Great Phone., Great Phone., This is a great p...
# 3      2  ...  [Best headset ever!!!., Excellent bluetooth he...
# 4      3  ...  [Excellent product for the price., Great produ...
# 5      4  ...        [Works great!., Works great., Works great.]
#
# [6 rows x 5 columns]

# %%
# Clustering model
hdbscan_model = HDBSCAN(min_cluster_size=10, min_samples = 10, metric='euclidean', prediction_data=True)
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, hdbscan_model=hdbscan_model)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
#     Topic  ...                                Representative_Docs
# 0      -1  ...  [I have been very happy with the 510 and have ...
# 1       0  ...  [Great Phone., It was a great phone., This is ...
# 2       1  ...  [The sound is clear and the people I talk to o...
# 3       2  ...  [Excellent product for the price., Great produ...
# 4       3  ...  [It was quite comfortable in the ear., It fits...
# 5       4  ...  [My headset works just peachy-keen., Best head...
# 6       5  ...  [Battery has no life., Battery life is also gr...
# 7       6  ...       [Works great., Works great!., Works great!.]
# 8       7  ...  [I purcashed this for the car charger and it d...
# 9       8  ...  [This case seems well made., Great case and pr...
# 10      9  ...  [I would recommend this., I would not recommen...
# 11     10  ...  [A PIECE OF JUNK THAT BROKE AFTER BEING ON MY ...
# 12     11  ...  [Bad Reception., I great reception all the tim...
# 13     12  ...  [disappointed., VERY DISAPPOINTED., very disap...
# 14     13  ...  [Great it was new packaged nice works good, no...
# 15     14  ...  [But, in any case, the best part is, you can d...
# 16     15  ...  [Pros:-Good camera - very nice pictures , also...
# 17     16  ...  [Worst Customer Service Ever., Customer servic...
# 18     17  ...  [Don't waste your money!., don't waste your mo...
# 19     18  ...  [The buttons for on and off are bad., It feels...
# 20     19  ...  [I love this device., The handsfree part works...
# 21     20  ...  [The color is even prettier than I thought it ...
# 22     21  ...  [The tracfonewebsite is user friendly and make...
# 23     22  ...  [I wish I could return the unit and get back m...
# 24     23  ...  [Best I've found so far .... I've tried 2 othe...
# 25     24  ...  [I advise EVERYONE DO NOT BE FOOLED!, Warning ...
#
# [26 rows x 5 columns]

# %%
# Clustering model
kmeans_model = KMeans(n_clusters=15)
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, hdbscan_model=kmeans_model)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#     Topic  ...                                Representative_Docs
# 0       0  ...  [The price was very good and with the free shi...
# 1       1  ...  [Great phone!., Great phone., This is a great ...
# 2       2  ...  [New Battery works great in phone., I got the ...
# 3       3  ...  [Great case and price!, Good case!., The look ...
# 4       4  ...  [very clear, quality sound and you don't have ...
# 5       5  ...  [Very easy to use., Easy to use., It is simple...
# 6       6  ...  [Worst customer service., Obviously they have ...
# 7       7  ...  [Waste of money., Dont waste your money..., Wh...
# 8       8  ...  [Love this headset!, Excellent bluetooth heads...
# 9       9  ...  [It was quite comfortable in the ear., It fits...
# 10     10  ...  [The calls drop, the phone comes on and off at...
# 11     11  ...  [Works great., (It works!), I've had this for ...
# 12     12  ...  [Display is excellent and camera is as good as...
# 13     13  ...  [I am very impressed with the job that Motorol...
# 14     14  ...  [I would recommend this., I would not recommen...
#
# [15 rows x 5 columns]

# %% [markdown]
# ### Hyperparameter Tuning for Language Embeddings

# %%
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, language="multilingual")

# %% [markdown]
# https://www.sbert.net/docs/pretrained_models.html

# %%
# Initiate a sentence transformer model
sentence_model = SentenceTransformer("paraphrase-albert-small-v2")
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, embedding_model=sentence_model)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
# Downloading (…)f333f/.gitattributes:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)4d423f333f/README.md:   0%|          | 0.00/4.03k [00:00<?, ?B/s]
# Downloading (…)423f333f/config.json:   0%|          | 0.00/827 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/46.7M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/245 [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/760k [00:00<?, ?B/s]
# Downloading (…)f333f/tokenizer.json:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# Downloading (…)23f333f/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
#     Topic  ...                                Representative_Docs
# 0      -1  ...  [If you like a loud buzzing to override all yo...
# 1       0  ...  [Excellent product for the price., Great produ...
# 2       1  ...  [Great phone., This is a great phone!., Great ...
# 3       2  ...  [You need at least 3 mins to get to your phone...
# 4       3  ...  [I've tried several different earpieces for my...
# 5       4  ...  [The handsfree part works fine, but then the c...
# 6       5  ...  [All three broke within two months of use., Fi...
# 7       6  ...  [Battery has no life., Battery life is also gr...
# 8       7  ...  [How can that be?The audio quality is poor., A...
# 9       8  ...  [disappointed., VERY DISAPPOINTED., very disap...
# 10      9  ...         [Works great., Works great!., (It works!)]
# 11     10  ...  [Excellent sound quality., very clear, quality...
# 12     11  ...  [It looks very nice., Its well-designed and ve...
# 13     12  ...  [It quit working after I'd used it for about 1...
# 14     13  ...  [Car charger as well as AC charger are include...
# 15     14  ...  [I love this bluetooth!, Great bluetooth!., Ex...
# 16     15  ...  [Don't buy it., Don't buy this product., Don't...
# 17     16  ...  [Sprint - terrible customer service., Worst Cu...
# 18     17  ...  [It didn't work, people can not hear me when I...
# 19     18  ...  [Waste of money., What a waste of money and ti...
# 20     19  ...  [Pros:-Good camera - very nice pictures , also...
# 21     20  ...  [But when I check voice mail at night, the key...
#
# [22 rows x 5 columns]

# %% [markdown]
# Hugging Face model hub has thousands of pre-trained models. In this example, we used an English model called distilroberta-base, loaded it in a Hugging Face pipeline, and pass the pipeline to the parameter embedding_model.

# %%
# Initiate a pretrained model
hf_model = pipeline("feature-extraction", model="distilroberta-base")
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, embedding_model=hf_model)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
#    Topic  ...                                Representative_Docs
# 0      0  ...  [I love my 350 headset.. My Jabra350 bluetooth...
# 1      1  ...  [WARNING - DO NOT BUY!!., DO NOT PURCHASE THIS...
#
# [2 rows x 5 columns]

# %% [markdown]
# Flair is an NLP (Natual Language Processing) library that allows us to choose almost any embedding models, or combine a few embedding models together.
#
# To use a single embedding model with Flair, we can pass the model name to TransformerDocumentEmbeddings, and use it as the input for the embedding_model option in BERTopic.

# %%
# Initiate a pretrained embedding model
roberta_model = TransformerDocumentEmbeddings('roberta-base')
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, embedding_model=roberta_model)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
#    Topic  ...                                Representative_Docs
# 0     -1  ...  [So I basically threw my money out the window ...
# 1      0  ...  [It is very comfortable on the ear., I've had ...
# 2      1  ...  [Don't buy this product., Don't buy it., Don't...
# 3      2  ...  [They do not last forever, but is not overly e...
#
# [4 rows x 5 columns]

# %% [markdown]
# To use multiple embedding models with Flair, we first need to initiate different pretrained embedding models, then use the StackedEmbeddings function to stack the models, and finally pass the stacked embeddings to the BERTopic embedding_model parameter.

# %%
# Initiate a pretrained embedding model
roberta_model = TransformerDocumentEmbeddings('roberta-base')
# Initiate another pretrained embedding model
glove_embedding = WordEmbeddings('crawl')
document_glove_embeddings = DocumentPoolEmbeddings([glove_embedding])
# Stack the two pretrained embedding models
stacked_embeddings = StackedEmbeddings(embeddings=[roberta_model, document_glove_embeddings])
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, embedding_model=stacked_embeddings)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
# 2023-06-19 09:32:26,339 https://flair.informatik.hu-berlin.de/resources/embeddings/token/en-fasttext-crawl-300d-1M.vectors.npy not found in cache, downloading to /tmp/tmpusfvqhvy
# 100%|██████████| 1.12G/1.12G [00:57<00:00, 20.8MB/s]
# 2023-06-19 09:33:24,314 copying /tmp/tmpusfvqhvy to cache at /root/.flair/embeddings/en-fasttext-crawl-300d-1M.vectors.npy
# 2023-06-19 09:33:28,865 removing temp file /tmp/tmpusfvqhvy
# 2023-06-19 09:33:29,490 https://flair.informatik.hu-berlin.de/resources/embeddings/token/en-fasttext-crawl-300d-1M not found in cache, downloading to /tmp/tmpqaw95djz
# 100%|██████████| 37.5M/37.5M [00:02<00:00, 18.4MB/s]
# 2023-06-19 09:33:31,975 copying /tmp/tmpqaw95djz to cache at /root/.flair/embeddings/en-fasttext-crawl-300d-1M
# 2023-06-19 09:33:32,025 removing temp file /tmp/tmpqaw95djz
#     Topic  ...                                Representative_Docs
# 0      -1  ...  [You need at least 3 mins to get to your phone...
# 1       0  ...  [It is simple to use and I like it., It fits m...
# 2       1  ...  [I've had this for nearly 2 years and it has w...
# 3       2  ...  [Excellent product for the price., Great produ...
# 4       3  ...  [Great it was new packaged nice works good, no...
# 5       4  ...  [I connected my wife's bluetooth,(Motorola HS8...
# 6       5  ...       [Great phone!., Great phone., Great phone!.]
# 7       6  ...  [While I managed to bend the leaf spring back ...
# 8       7  ...  [DO NOT PURCHASE THIS PHONE., AFTER ARGUING WI...
# 9       8  ...  [disappointed., very disappointed., VERY DISAP...
# 10      9  ...  [I would highly recommend this product., I wou...
# 11     10  ...  [It defeats the purpose of a bluetooth headset...
# 12     11  ...  [After 3 months, screen just went black all of...
# 13     12  ...  [don't waste your money., Don't waste your mon...
# 14     13  ...  [poor quality and service., Audio Quality is p...
# 15     14  ...  [Battery has no life., Battery life is real go...
# 16     15  ...        [Works great., Works great!., Works great.]
# 17     16  ...  [Verizon's bills, however, are difficult to un...
# 18     17  ...  [Unfortunately it will not recharge my iPhone ...
# 19     18  ...  [But now that it is "out of warranty" the same...
#
# [20 rows x 5 columns]

# %% [markdown]
# ### Hyperparameter Tuning for Number of Topics

# %% [markdown]
# BERTopic uses the number of clusters created by the HDBSCAN model as the number of topics by default, but we can reduce the number of topics by changing the value of the nr_topics parameter.
#
# * nr_topics=None indicates that there is no topic reduction.
# * nr_topics=auto indicates an automatic topic reduction of the HDBSCAN results by merging topics close to each other.
# * nr_topics=15 indicates that the target number of topics is 15.
# * nr_topics value should always be smaller than the number of topics created by nr_topics=None.

# %%
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, nr_topics=15)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
#     Topic  ...                                Representative_Docs
# 0      -1  ...  [I am very impressed with the job that Motorol...
# 1       0  ...  [New Battery works great in phone., It was a g...
# 2       1  ...  [This is simply the BEST bluetooth headset for...
# 3       2  ...  [Excellent product for the price., Great produ...
# 4       3  ...  [I am not impressed with this and i would not ...
# 5       4  ...  [Worst Customer Service Ever., Customer servic...
# 6       5  ...        [Works great!., Works great., Works great.]
# 7       6  ...  [This case seems well made., Great case and pr...
# 8       7  ...  [Don't waste your money!., Dont waste your mon...
# 9       8  ...  [Bad Reception., I great reception all the tim...
# 10      9  ...  [Disappointed!., very disappointed., VERY DISA...
# 11     10  ...  [Pros:-Good camera - very nice pictures , also...
# 12     11  ...  [Reaching for the bottom row is uncomfortable,...
# 13     12  ...  [It looks very nice., The look of it is very s...
# 14     13  ...  [I wish I could return the unit and get back m...
#
# [15 rows x 5 columns]

# %% [markdown]
# When the text corpus is large, training a BERTopic model can take a long time. Rerunning the model each time we change the number of topics can waste a lot of time and resources. The good news is that the BERTopic package has a **reduce_topics** method that uses the existing model information to do a topic reduction.

# %%
# Further reduce topics
topic_model.reduce_topics(amz_review['review'], nr_topics=10)
# Get the list of topics
topic_model.get_topic_info()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
#    Topic  ...                                Representative_Docs
# 0     -1  ...  [I am very impressed with the job that Motorol...
# 1      0  ...  [I've had this bluetoooth headset for some tim...
# 2      1  ...  [For the price on Amazon, it is an excellent p...
# 3      2  ...  [This case seems well made., Great case and pr...
# 4      3  ...  [Don't waste your money!., don't waste your mo...
# 5      4  ...  [Disappointed!., very disappointed., VERY DISA...
# 6      5  ...  [Pros:-Good camera - very nice pictures , also...
# 7      6  ...  [Reaching for the bottom row is uncomfortable,...
# 8      7  ...  [It looks very nice., Its well-designed and ve...
# 9      8  ...  [I wish I could return the unit and get back m...
#
# [10 rows x 5 columns]

# %% [markdown]
# Another way of adjusting the number of topics is to control the minimum number of documents in a topic. We can set up this value by the parameter min_topic_size.
#
# * A low value for min_topic_size allows fewer documents to form a topic, so the topic model produces more topics.
# * A high value for min_topic_size requires a lot of documents to form a topic, so the topic model produces fewer topics.
# * The default value for min_topic_size is 10. A general guideline for setting min_topic_size is to set up a low value for a smaller dataset, and a high value for a larger dataset.
#
# Setting min_topic_size is the same as setting min_cluster_size in HDBSCAN.

# %%
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, min_topic_size=25)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
#    Topic  ...                                Representative_Docs
# 0     -1  ...  [My experience was terrible..... This was my f...
# 1      0  ...  [The price was very good and with the free shi...
# 2      1  ...  [Great phone., Great phone., This is a great p...
# 3      2  ...  [Other than that, the leather is nice and soft...
# 4      3  ...  [very clear, quality sound and you don't have ...
# 5      4  ...  [Best headset ever!!!., Love this headset!, Th...
# 6      5  ...  [I've tried several different earpieces for my...
# 7      6  ...  [He was very impressed when going from the ori...
# 8      7  ...  [Great charger., I purcashed this for the car ...
#
# [9 rows x 5 columns]

# %% [markdown]
# ### Hyperparameter for Top Words

# %% [markdown]
# **n_gram_range** is used to specify the range of n-grams included in the topic model.
# **top_n_words** controls how many words are used to describe the topic.

# %%
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, n_gram_range=(1, 3))
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
#     Topic  ...                                Representative_Docs
# 0      -1  ...  [The calls drop, the phone comes on and off at...
# 1       0  ...  [Great phone!., If you like a loud buzzing to ...
# 2       1  ...  [It is easy to turn on and off when you are in...
# 3       2  ...  [Great product for the price!., Excellent prod...
# 4       3  ...  [This is so embarassing and also my ears hurt ...
# 5       4  ...  [If the two were seperated by a mere 5+ ft I s...
# 6       5  ...  [The battery life is highly unacceptable., You...
# 7       6  ...  [Works great!., Everything worked on the first...
# 8       7  ...  [it did not work in my cell phone plug i am ve...
# 9       8  ...  [When I placed my treo into the case, not only...
# 10      9  ...  [I am not impressed with this and i would not ...
# 11     10  ...  [A PIECE OF JUNK THAT BROKE AFTER BEING ON MY ...
# 12     11  ...  [It is practically useless and did not add any...
# 13     12  ...  [I'm very disappointed with my decision., VERY...
# 14     13  ...  [The seller is very understanding and patient,...
# 15     14  ...  [Bluetooth does not work, phone locks up, scre...
# 16     15  ...  [The camera, although rated at an impressive 1...
# 17     16  ...  [Obviously they have a terrible customer servi...
# 18     17  ...  [don't waste your money., Don't waste your mon...
# 19     18  ...  [The keyboard is a nice compromise between a f...
# 20     19  ...  [This little device has transformed my organiz...
# 21     20  ...  [I really recommend this faceplates since it l...
# 22     21  ...  [Very easy to use., It's very convenient and s...
# 23     22  ...  [This company charge me a restocking fee and s...
# 24     23  ...  [Bluetooth range is good - a few days ago I le...
# 25     24  ...  [WARNING - DO NOT BUY!!., I advise EVERYONE DO...
#
# [26 rows x 5 columns]

# %%
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, top_n_words=5)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Got top topic words
topic_model.get_topic(1)
# Out:
# [('sound', 0.06238531040131652),
#  ('hear', 0.05110186293603991),
#  ('quality', 0.04487960503083769),
#  ('the', 0.040710454262311985),
#  ('volume', 0.03832639720202994)]

# %% [markdown]
# ### Hyperparameters for Words Universe

# %% [markdown]
# There are two ways to control how many words are used in CountVectorizer and c-TF-IDF.
#
# min_df sets a threshold for the required word frequency. For example, min_df=10 indicates that any words that appeared less than 10 times in the corpus will not be included in the c-TF-IDF calculation. A general guideline is to set a high min_df value for a large corpus and a low value for a small corpus.
# max_features indicates the maximum number of words to include for the c-TF-IDF calculation. max_features=1_000 means that the top 1000 words with the highest frequency in the corpus will be included.

# %%
# Count vectorizer
vectorizer_model = CountVectorizer(min_df=10)
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, vectorizer_model=vectorizer_model)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
#     Topic  ...                                Representative_Docs
# 0      -1  ...  [The calls drop, the phone comes on and off at...
# 1       0  ...  [The phone loads super!, This is hands down th...
# 2       1  ...  [And the sound quality is great., very clear, ...
# 3       2  ...  [Great product., A pretty good product., Good ...
# 4       3  ...  [I usually don't like headbands but this one i...
# 5       4  ...  [I was looking for this headset for a long tim...
# 6       5  ...  [Appears to actually outperform the original b...
# 7       6  ...        [Works great., Works great., Works great!.]
# 8       7  ...  [I got the car charger and not even after a we...
# 9       8  ...  [Looks good in the picture, but this case was ...
# 10      9  ...  [I would highly recommend this., Would recomme...
# 11     10  ...        [Bad Quality., Poor quality., Low Quality.]
# 12     11  ...  [The range is very decent, I've been able to r...
# 13     12  ...  [Very Displeased., VERY DISAPPOINTED., very di...
# 14     13  ...  [Last time buying from you., Great it was new ...
# 15     14  ...  [Does not work for listening to music with the...
# 16     15  ...  [You also cannot take pictures with it in the ...
# 17     16  ...  [Thank you for such great service., Too bad yo...
# 18     17  ...  [Don't waste your money!., don't waste your mo...
# 19     18  ...  [The buttons for on and off are bad., It feels...
# 20     19  ...  [The file browser offers all the options that ...
# 21     20  ...  [Its well-designed and very sharp -- the blue ...
# 22     21  ...  [Blue Ant is easy to use., It is a joy to use....
# 23     22  ...  [I did not bother contacting the company for f...
# 24     23  ...  [The one big drawback of the MP3 player is tha...
# 25     24  ...  [Don't buy it., dont buy it., WARNING - DO NOT...
#
# [26 rows x 5 columns]

# %%
# Count vectorizer
vectorizer_model = CountVectorizer(max_features=1_000)
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, vectorizer_model=vectorizer_model)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
#     Topic  ...                                Representative_Docs
# 0      -1  ...  [I own a Jabra Earset and was very happy with ...
# 1       0  ...  [O my gosh the best phone I have ever had., It...
# 2       1  ...  [The sound is clear and the people I talk to o...
# 3       2  ...  [Excellent product for the price., Great produ...
# 4       3  ...  [Painful on the ear., It fits my ear well and ...
# 5       4  ...  [My headset works just peachy-keen., Love this...
# 6       5  ...  [Battery has no life., The battery works great...
# 7       6  ...       [Works great., Works great!., Works great!.]
# 8       7  ...  [I purcashed this for the car charger and it d...
# 9       8  ...  [The case is great and works fine with the 680...
# 10      9  ...  [I would recommend this., I would not recommen...
# 11     10  ...  [Pretty piece of junk., Piece of Junk., Saggy,...
# 12     11  ...  [The reception has been generally good., The r...
# 13     12  ...  [Disappointed!., VERY DISAPPOINTED., very disa...
# 14     13  ...  [Great it was new packaged nice works good, no...
# 15     14  ...  [I had ordered a motorola data cable, got a ve...
# 16     15  ...  [Pros:-Good camera - very nice pictures , also...
# 17     16  ...  [Worst Customer Service Ever., Customer servic...
# 18     17  ...  [Don't waste your money!., don't waste your mo...
# 19     18  ...  [However, the keypads are so tinny that I some...
# 20     19  ...  [The handsfree part works fine, but then the c...
# 21     20  ...  [It looks very nice., Its well-designed and ve...
# 22     21  ...  [Blue Ant is easy to use., Very easy to use., ...
# 23     22  ...  [I contacted the company and they told me that...
# 24     23  ...  [Best I've found so far .... I've tried 2 othe...
# 25     24  ...  [Stay Away From the Q!., Warning - Stay away.,...
#
# [26 rows x 5 columns]

# %% [markdown]
# ### Hyperparameter for Diversifying Topic Representation

# %% [markdown]
# The hyperparameter diversity helps to remove the words with the same or similar meanings. It has a range of 0 to 1, where 0 means least diversity and 1 means most diversity.

# %%
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, diversity=0.8)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f466f5cd6991> in <cell line: 2>()
#       1 # Initiate BERTopic
# ----> 2 topic_model = BERTopic(umap_model=umap_model, diversity=0.8)
#       3 # Run BERTopic model
#       4 topics = topic_model.fit_transform(amz_review['review'])
#       5 # Get the list of topics
#
# TypeError: BERTopic.__init__() got an unexpected keyword argument 'diversity'

# %% [markdown]
# ### Hyperparameter for Stopwords

# %% [markdown]
# After creating the topics, if the top words representing the topics contain stopwords, we can remove the stopwords using stop_words="english" with CountVectorizer.

# %%
# Count vectorizer
vectorizer_model = CountVectorizer(stop_words="english")
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, vectorizer_model=vectorizer_model)
# Run BERTopic model
topics = topic_model.fit_transform(amz_review['review'])
# Get the list of topics
topic_model.get_topic_info()
# Out:
#     Topic  ...                                Representative_Docs
# 0      -1  ...  [The pairing of the two devices was so easy it...
# 1       0  ...  [Great phone., Great Phone., This is a great p...
# 2       1  ...  [The sound quality is excellent as well., Poor...
# 3       2  ...  [Excellent product for the price., Great produ...
# 4       3  ...  [I've tried several different earpieces for my...
# 5       4  ...  [Love this headset!, Its the best headset I ha...
# 6       5  ...  [The battery works great!, Battery life is als...
# 7       6  ...        [Works great., Works great!., Works great.]
# 8       7  ...  [it did not work in my cell phone plug i am ve...
# 9       8  ...  [Great case and price!, This case seems well m...
# 10      9  ...  [I am not impressed with this and i would not ...
# 11     10  ...  [A PIECE OF JUNK THAT BROKE AFTER BEING ON MY ...
# 12     11  ...  [The reception through this headset is excelle...
# 13     12  ...  [disappointed., VERY DISAPPOINTED., Disappoint...
# 14     13  ...  [Seller shipped quickly and much cheaper than ...
# 15     14  ...  [Bluetooth does not work, phone locks up, scre...
# 16     15  ...  [Display is excellent and camera is as good as...
# 17     16  ...  [Customer service was terrible., Worst Custome...
# 18     17  ...  [It was a waste of my money., Dont waste your ...
# 19     18  ...  [The keyboard is a nice compromise between a f...
# 20     19  ...  [The handsfree part works fine, but then the c...
# 21     20  ...  [The color is even prettier than I thought it ...
# 22     21  ...  [The tracfonewebsite is user friendly and make...
# 23     22  ...  [I did not bother contacting the company for f...
# 24     23  ...  [Great bluetooth!., The one big drawback of th...
# 25     24  ...  [Stay Away From the Q!., WARNING - DO NOT BUY!...
#
# [26 rows x 5 columns]

# %% [markdown]
# ### Hyperparameter for Topic Probability Output

# %% [markdown]
# * When calculate_probabilities = True, the probabilities of each document belonging to each topic are calculated. The topic with the highest probability is the predicted topic for a new document. This probability represents how confident we are about finding the topic in the document.
#
# * When calculate_probabilities = False, the probabilities of each document belonging to each topic are not calculated. This saves computation time and cost. If there is no new document to predict, we do not need to calculate the probabilities.
#
# We can visualize the probabilities using visualize_distribution, and pass in the document index. visualize_distribution has the default probability threshold of 0.015, so only the topic with a probability greater than 0.015 will be included.

# %%
# Initiate BERTopic
topic_model = BERTopic(umap_model=umap_model, calculate_probabilities=True)
# Run BERTopic model
topics, probablity = topic_model.fit_transform(amz_review['review'])
# Visualize probability distribution
topic_model.visualize_distribution(topic_model.probabilities_[0], min_probability=0.015)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ca82ff12-19cc-4e51-9bc3-17cb8c24135c" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca82ff12-19cc-4e51-9bc3-17cb8c24135c")) {                    Plotly.newPlot(                        "ca82ff12-19cc-4e51-9bc3-17cb8c24135c",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.02600691681665258,0.12686490912841833,0.031852947951372175,0.015322375472886033,0.015343514483195918,0.01943850888770607],"y":["<b>Topic 5</b>: battery_life_original_th...","<b>Topic 7</b>: charger_charge_car_plug_...","<b>Topic 14</b>: cable_work_with_my_lapt...","<b>Topic 18</b>: buttons_keyboard_are_di...","<b>Topic 19</b>: device_hands_handsfree_...","<b>Topic 23</b>: bluetooth_few_best_look..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde72 ...

# %%
# Check the content for the first review
amz_review['review'][0]
# Out:
# 'So there is no way for me to plug it in here in the US unless I go by a converter.'

# %%
# Get probabilities for all topics
topic_model.probabilities_[0]
# Out:
# array([0.01304336, 0.01299055, 0.00881539, 0.01149096, 0.01389758,
#        0.02600692, 0.01078748, 0.12686491, 0.01086359, 0.01014737,
#        0.01166604, 0.0129515 , 0.00953966, 0.0097009 , 0.03185295,
#        0.01051503, 0.01180338, 0.00837704, 0.01532238, 0.01534351,
#        0.01160797, 0.01479929, 0.01068419, 0.01943851, 0.00956005])
